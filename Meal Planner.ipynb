# %%
print('Food Item Names Codes: a=Rice, b=Wheat Flour, c=Maida, d=Chana, e=Chana Dal, f=Milk, g=Curd, h=Potato, i=Tomato, j=Salt & Spices, k=Sugar, l=Mustard Oil, m=Ghee, n=French Beans, o=Onions, p=Carrot')
print("Enter the Food Item Names Codes in the box without any space in-between:")
My_list= list(input())
list1 = ['a','c','f','h','i','j','k','l','m','o']
list2 = ['c','g','h','i','j','l','m','o']
list3 = ['c','d','h','i','j','l','m','o']
list4 = ['a','e','h','i','j','l','o']
list5 = ['a','g','h','i','j','l','o']
list6 = ['b','g','h','i','j','l','o']
list7 = ['b','e','h','i','j','l','o']
list8 = ['b','d','h','i','j','l','o']
list9 = ['a','j','m','o','n','p']
list10 = ['b','h','i','j','l','o']
list11 = ['c','f','k','m','p']
list12 = ['b','f','k','m','p']
list13 = ['f','k','m','p']
check1 = all(item in My_list for item in list1)
check2 = all(item in My_list for item in list2)
check3 = all(item in My_list for item in list3)
check4 = all(item in My_list for item in list4)
check5 = all(item in My_list for item in list5)
check6 = all(item in My_list for item in list6)
check7 = all(item in My_list for item in list7)
check8 = all(item in My_list for item in list8)
check9 = all(item in My_list for item in list9)
check10 = all(item in My_list for item in list10)
check11 = all(item in My_list for item in list11)
check12 = all(item in My_list for item in list12)
check13 = all(item in My_list for item in list13)
print('You can prepare the following meals today:')
if check1 is True:
    print('Puri Kheer Sabji')
    if check2 is True:
        print('Puri Sabji')
        if check3 is True:
            print('Puri Chole')
            if check4 is True:
                print('Dal Bhaat Sabji')
                if check5 is True:
                    print('Dahi Bhaat Sabji')
                    if check6 is True:
                        print('Dahi Roti Sabji')
                        if check7 is True:
                            print('Dal Roti Sabji')
                            if check8 is True:
                                print('Roti Chole')
                                if check9 is True:
                                    print('Roti Sabji')
                                    if check10 is True:
                                        print('Fried Rice')
                                        if check11 is True:
                                            print('Gajar ka halwa Puri')
                                            if check12 is True:
                                                print('Gajar ka halwa Roti')
                                                if check13 is True:
                                                    print('Gajar ka halwa')
else:
    print('Nothing to prepare. Go have lunch outside')
# Out:
# Food Item Names Codes: a=Rice, b=Wheat Flour, c=Maida, d=Chana, e=Chana Dal, f=Milk, g=Curd, h=Potato, i=Tomato, j=Salt & Spices, k=Sugar, l=Mustard Oil, m=Ghee, n=French Beans, o=Onions, p=Carrot
# Enter the Food Item Names Codes in the box without any space in-between:
